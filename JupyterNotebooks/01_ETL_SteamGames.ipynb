# %% [markdown]
# ### Importaciones

# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2
import utils
import warnings
warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
### Cargo Archivo
df_games = pd.read_json('../data/output_steam_games.json', lines=True)

# %%
df_games.head()
# Out:
#   publisher genres app_name title   url release_date  tags reviews_url specs  \
# 0      None   None     None  None  None         None  None        None  None
# 1      None   None     None  None  None         None  None        None  None
# 2      None   None     None  None  None         None  None        None  None
# 3      None   None     None  None  None         None  None        None  None
# 4      None   None     None  None  None         None  None        None  None
#
#   price  early_access  id developer
# 0  None           NaN NaN      None
# 1  None           NaN NaN      None
# 2  None           NaN NaN      None
# 3  None           NaN NaN      None
# 4  None           NaN NaN      None

# %%
### Elimino elementos vacios
df_games = df_games.dropna(how='all').reset_index(drop=True)
df_games.head()
# Out:
#           publisher                                             genres  \
# 0         Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1  Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2      Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3              彼岸领域                        [Action, Adventure, Casual]
# 4              None                                               None
#
#                   app_name                    title  \
# 0      Lost Summoner Kitty      Lost Summoner Kitty
# 1                Ironbound                Ironbound
# 2  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 3                  弹炸人2222                  弹炸人2222
# 4            Log Challenge                     None
#
#                                                  url release_date  \
# 0  http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# 1  http://store.steampowered.com/app/643980/Ironb...   2018-01-04
# ...

# %%
#verifico con la funcion creada, los tipos de datos del DF
utils.types_data_df(df_games)
# Out:
#     nombre_campo                                         tipo_datos  \
# 0      publisher                [<class 'str'>, <class 'NoneType'>]
# 1         genres               [<class 'list'>, <class 'NoneType'>]
# 2       app_name                [<class 'str'>, <class 'NoneType'>]
# 3          title                [<class 'str'>, <class 'NoneType'>]
# 4            url                                    [<class 'str'>]
# 5   release_date                [<class 'str'>, <class 'NoneType'>]
# 6           tags               [<class 'list'>, <class 'NoneType'>]
# 7    reviews_url                [<class 'str'>, <class 'NoneType'>]
# 8          specs               [<class 'list'>, <class 'NoneType'>]
# 9          price  [<class 'float'>, <class 'str'>, <class 'NoneT...
# 10  early_access                                  [<class 'float'>]
# 11            id                                  [<class 'float'>]
# 12     developer                [<class 'str'>, <class 'NoneType'>]
#
# ...

# %%
# Se visualizan Listas en columnas genres, tags,specs
# Se verifica contenido

df_games['genres'][0]
# Out:
# ['Action', 'Casual', 'Indie', 'Simulation', 'Strategy']

# %% [markdown]
# #### Descripción del DF
#
# Este conjunto contiene 13 columnas y quedó con 32135 filas luego de borrar las filas de NaN, aún contienen nulos en algunas columnas. Las columnas que contiene son:
#
#     *publisher: es la empresa publicadora del contenido.
#     *genres: es el género del item, es decir, del juego. Esta formado por una lista de uno o mas géneros por registro.
#     *app_name: es el nombre del item, es decir, del juego.
#     *title: es el título del item.
#     *url: es la url del juego.
#     *release_date: es la fecha de lanzamiento del item en formato 2018-01-04.
#     *tags: es la etiqueta del contenido. Esta formado por una lista de uno o mas etiquetas por registro.
#     *reviews_url: es la url donde se encuentra el review de ese juego.
#     *specs: son especificaciones de cada item. Es una lista con uno o mas string con las especificaciones.
#     *price: es el precio del item.
#     *early_access: indica el acceso temprano con un True/False.
#     *id: es el identificador único del contenido.
#     *developer: es el desarrollador del contenido.

# %%
#Se analizan duplicados desde la columna del id item.
duplicados = df_games.duplicated(subset=['id'], keep=False)

# Filtro
duplicados_df = df_games[duplicados]

# Muestra el DataFrame con los duplicados
duplicados_df
# Out:
#                                                publisher               genres  \
# 74                                                  None                 None
# 13894                                 Bethesda Softworks             [Action]
# 14573                                 Bethesda Softworks             [Action]
# 30961  Warner Bros. Interactive Entertainment, Feral ...  [Action, Adventure]
#
#                                              app_name  \
# 74                                               None
# 13894                Wolfenstein II: The New Colossus
# 14573                Wolfenstein II: The New Colossus
# 30961  Batman: Arkham City - Game of the Year Edition
#
#                                                 title  \
# 74                                               None
# 13894                Wolfenstein II: The New Colossus
# 14573                Wolfenstein II: The New Colossus
# 30961  Batman: Arkham City - Game of the Year Edition
#
# ...

# %%
#Existen dos items duplicados. 
# 1 - el 'id' 612880 que se observa es el mismo registro en los dos casos. 
# 2 - el id  NaN y la primera aparición presenta mas cantidad de NaN que la segunda aparición.
df_games[df_games['developer']=='Rocksteady Studios,Feral Interactive (Mac)']
# Out:
#                                                publisher               genres  \
# 1068   Warner Bros. Interactive Entertainment, Feral ...  [Action, Adventure]
# 30961  Warner Bros. Interactive Entertainment, Feral ...  [Action, Adventure]
# 31617  Warner Bros. Interactive Entertainment, Feral ...  [Action, Adventure]
#
#                                              app_name  \
# 1068   Batman: Arkham City - Game of the Year Edition
# 30961  Batman: Arkham City - Game of the Year Edition
# 31617  Batman: Arkham Asylum Game of the Year Edition
#
#                                                 title  \
# 1068   Batman: Arkham City - Game of the Year Edition
# 30961  Batman: Arkham City - Game of the Year Edition
# 31617  Batman: Arkham Asylum Game of the Year Edition
#
#                                                      url release_date  \
# 1068   http://store.steampowered.com/app/200260/Batma...   2012-09-07
# ...

# %%
#Se observa no tiene 'id' es el 'id' 200260 y esta incompleto. 
# se eliminan los index deseados
index_delete = [14573, 74, 30961]
df_games = df_games.drop(index_delete)

# %%
#Verifico duplicados:
duplicados = df_games.duplicated(subset=['id'], keep=False)

# Filtro
duplicados_df = df_games[duplicados]

# Muestra el DataFrame con los duplicados
duplicados_df
# Out:
# Empty DataFrame
# Columns: [publisher, genres, app_name, title, url, release_date, tags, reviews_url, specs, price, early_access, id, developer]
# Index: []

# %%
# Verifico cantidad de elementos de release_date, para luego extraer el año
df_games['release_date'].value_counts()
# Out:
# release_date
# 2012-10-16    100
# 2017-08-31     92
# 2017-09-26     89
# 2017-06-21     82
# 2017-07-25     78
#              ...
# 1988-04-16      1
# 2013-08-24      1
# 2011-05-07      1
# 2010-08-21      1
# 2018-10-01      1
# Name: count, Length: 3582, dtype: int64

# %%
# Creo columna nueva con el año
df_games['release_anio'] = df_games['release_date'].apply(utils.extract_anio_release)
# elimina la columna 'release_date'
df_games = df_games.drop('release_date', axis=1)
df_games.head()
# Out:
#           publisher                                             genres  \
# 0         Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1  Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2      Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3              彼岸领域                        [Action, Adventure, Casual]
# 4              None                                               None
#
#                   app_name                    title  \
# 0      Lost Summoner Kitty      Lost Summoner Kitty
# 1                Ironbound                Ironbound
# 2  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 3                  弹炸人2222                  弹炸人2222
# 4            Log Challenge                     None
#
#                                                  url  \
# 0  http://store.steampowered.com/app/761140/Lost_...
# 1  http://store.steampowered.com/app/643980/Ironb...
# 2  http://store.steampowered.com/app/670290/Real_...
# ...

# %%
#Verifico
df_games['release_anio'].unique()
# Out:
# array(['2018', '2017', None, 'Dato no disponible', '1997', '1998', '2016',
#        '2006', '2005', '2003', '2007', '2002', '2000', '1995', '1996',
#        '1994', '2001', '1993', '2004', '1999', '2008', '2009', '1992',
#        '1989', '2010', '2011', '2013', '2012', '2014', '1983', '1984',
#        '2015', '1990', '1988', '1991', '1985', '1982', '1987', '1981',
#        '1986', '2021', '2019', '1975', '1970', '1980'], dtype=object)

# %%
#Manejo columna 'price'
df_games['price'] = df_games['price'].apply(utils.replace_float)
df_games['price'].dtype
# Out:
# dtype('float64')

# %%
## Transformación de las columnas 'publisher', 'app_name', 'title', 'developer'
#Se cambia nulos por 'No disponible'

columns = ['publisher', 'app_name', 'title', 'developer']
# Se rellenan los nulos
df_tocomplete = df_games[columns].fillna('Sin dato disponible')
# Se borran las columnas originales y se concatenan las rellenas con todo el dataframe
df_games = pd.concat([df_games.drop(columns, axis=1), df_tocomplete], axis=1)
df_games.head()
# Out:
#                                               genres  \
# 0      [Action, Casual, Indie, Simulation, Strategy]
# 1               [Free to Play, Indie, RPG, Strategy]
# 2  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                        [Action, Adventure, Casual]
# 4                                               None
#
#                                                  url  \
# 0  http://store.steampowered.com/app/761140/Lost_...
# 1  http://store.steampowered.com/app/643980/Ironb...
# 2  http://store.steampowered.com/app/670290/Real_...
# 3     http://store.steampowered.com/app/767400/2222/
# 4  http://store.steampowered.com/app/773570/Log_C...
#
#                                                 tags  \
# 0      [Strategy, Action, Indie, Casual, Simulation]
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...
# 2  [Free to Play, Simulation, Sports, Casual, Ind...
# 3                        [Action, Adventure, Casual]
# ...

# %%
#Transformación columna 'genres'
# lista de los distintos géneros de los videojuegos. Se necesita hacer una columna con cada género.

df_games = df_games.explode('genres')
df_games = df_games.dropna(subset=['genres'])
df_games.head()
# Out:
#        genres                                                url  \
# 0      Action  http://store.steampowered.com/app/761140/Lost_...
# 0      Casual  http://store.steampowered.com/app/761140/Lost_...
# 0       Indie  http://store.steampowered.com/app/761140/Lost_...
# 0  Simulation  http://store.steampowered.com/app/761140/Lost_...
# 0    Strategy  http://store.steampowered.com/app/761140/Lost_...
#
#                                             tags  \
# 0  [Strategy, Action, Indie, Casual, Simulation]
# 0  [Strategy, Action, Indie, Casual, Simulation]
# 0  [Strategy, Action, Indie, Casual, Simulation]
# 0  [Strategy, Action, Indie, Casual, Simulation]
# 0  [Strategy, Action, Indie, Casual, Simulation]
#
#                                          reviews_url            specs  price  \
# 0  http://steamcommunity.com/app/761140/reviews/?...  [Single-player]   4.99
# 0  http://steamcommunity.com/app/761140/reviews/?...  [Single-player]   4.99
# ...

# %%
#Columnas 'tags', 'specs', 'url' y 'reviews_url'
#Estas columnas, en esta primer instancia, no se utilizarán para las consultas de la API ni para el modelo de recomendación, por lo tanto se eliminan del dataframe.
df_games = df_games.drop(['tags', 'specs', 'url', 'reviews_url'], axis=1)
df_games.columns
# Out:
# Index(['genres', 'price', 'early_access', 'id', 'release_anio', 'publisher',
#        'app_name', 'title', 'developer'],
#       dtype='object')

# %% [markdown]
# ### GUARDO ARCHIVO LIMPIO

# %%
df_games.to_csv('../data/steam_games_limpo.csv', index=False)

# %%
df_games.to_parquet('../data/steam_games_limpo.parquet')
