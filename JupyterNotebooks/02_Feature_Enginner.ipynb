# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# %load_ext autoreload
# %autoreload 2
import utils

import warnings
warnings.filterwarnings("ignore")

# %%
#Extraigo datos:

df_reviews = pd.read_parquet('../data/user_reviews_limpo.parquet')
df_games = pd.read_parquet('../data/steam_games_limpo.parquet')
df_items = pd.read_parquet('../data/user_items_limpo.parquet')

# %% [markdown]
# ## Análisis de sentimientos
#
# Se pide crear una nueva columna llamada 'sentiment_analysis' que reemplace a 'reviews_review' donde se realice un análisis de sentimiento de los comentarios con la siguiente escala:
#
#     *0 si es malo,
#     *1 si es neutral o esta sin review
#     *2 si es positivo.
#
# Dado que el objetivo de este proyecto es realizar una prueba de concepto, consiguiendo un producto mínimo viable, se realiza un análisis de sentimiento básico utilizando TextBlob que es una biblioteca de procesamiento de lenguaje natural (NLP) en Python. El objetivo de esta metodología es asignar un valor numérico a un texto, en este caso a los comentarios que los usuarios dejaron para un juego determinado, para representar si el sentimiento expresado en el texto es negativo, neutral o positivo.
#
# Esta metodología toma una revisión de texto como entrada, utiliza TextBlob para calcular la polaridad de sentimiento y luego clasifica la revisión como negativa, neutral o positiva en función de la polaridad calculada. En este caso, se consideraron las polaridades por defecto del modelo, el cuál utiliza umbrales -0.2 y 0.2, siendo polaridades negativas por debajo de -0.2, positivas por encima de 0.2 y neutrales entre medio de ambos.

# %%
df_reviews['sentiment_analysis'] = df_reviews['reviews_review'].apply(utils.sentiment_analysis)
df_reviews.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#    reviews_item_id                                  reviews_helpful  \
# 0             1250                                   No ratings yet
# 1           251610  15 of 20 people (75%) found this review helpful
# 2           248820                                   No ratings yet
# 3           250320   2 of 2 people (100%) found this review helpful
# 4           211420  35 of 43 people (81%) found this review helpful
#
#    reviews_recommend                                     reviews_review  \
# 0               True  Simple yet with great replayability. In my opi...
# 1               True  I know what you think when you see this title ...
# 2               True  A suitably punishing roguelike platformer.  Wi...
# 3               True  This game... is so fun. The fight sequences ha...
# 4               True                                            Git gud
#
#        reviews_date  sentiment_analysis
# 0        2011-11-05                   1
# 1        2014-06-24                   1
# 2  Formato inválido                   2
# 3        2013-10-14                   2
# 4        2014-04-15                   1

# %%
#Ya teniendo las reseñas como valor numerico, elimino la columna "reviews_review"
df_reviews = df_reviews.drop(columns=['reviews_review'])
df_reviews.columns
# Out:
# Index(['user_id', 'user_url', 'reviews_item_id', 'reviews_helpful',
#        'reviews_recommend', 'reviews_date', 'sentiment_analysis'],
#       dtype='object')

# %%
#renombre columna ID para posterior Merge
nuevos_nombres = {'id': 'item_id'}

df_games_rename = df_games.rename(columns=nuevos_nombres)
df_games_rename.head()
# Out:
#        genres  price  early_access   item_id release_anio  publisher  \
# 0      Action   4.99           0.0  761140.0         2018  Kotoshiro
# 0      Casual   4.99           0.0  761140.0         2018  Kotoshiro
# 0       Indie   4.99           0.0  761140.0         2018  Kotoshiro
# 0  Simulation   4.99           0.0  761140.0         2018  Kotoshiro
# 0    Strategy   4.99           0.0  761140.0         2018  Kotoshiro
#
#               app_name                title  developer
# 0  Lost Summoner Kitty  Lost Summoner Kitty  Kotoshiro
# 0  Lost Summoner Kitty  Lost Summoner Kitty  Kotoshiro
# 0  Lost Summoner Kitty  Lost Summoner Kitty  Kotoshiro
# 0  Lost Summoner Kitty  Lost Summoner Kitty  Kotoshiro
# 0  Lost Summoner Kitty  Lost Summoner Kitty  Kotoshiro

# %%
df_games_rename['item_id'].astype(int)
# Out:
# 0        761140
# 0        761140
# 0        761140
# 0        761140
# 0        761140
#           ...
# 32132    610660
# 32132    610660
# 32132    610660
# 32133    658870
# 32133    658870
# Name: item_id, Length: 71551, dtype: int32

# %% [markdown]
# ### Se crea un df_datosLimpios
# Para elegir en post los datos a exportar

# %%
df_datosLimpios = pd.merge(df_items, df_reviews, how='inner', on= 'user_id')
df_datosLimpios.head()
df_datosLimpios
# Out:
#          item_id                  item_name  playtime_forever  \
# 0             10             Counter-Strike                 6
# 1             10             Counter-Strike                 6
# 2             10             Counter-Strike                 6
# 3             20      Team Fortress Classic                 0
# 4             20      Team Fortress Classic                 0
# ...          ...                        ...               ...
# 5983155    57300  Amnesia: The Dark Descent                 0
# 5983156    57300  Amnesia: The Dark Descent                 0
# 5983157   417860              Emily is Away                36
# 5983158   417860              Emily is Away                36
# 5983159   417860              Emily is Away                36
#
#                   steam_id  items_count            user_id  \
# 0        76561197970982479          277  76561197970982479
# 1        76561197970982479          277  76561197970982479
# 2        76561197970982479          277  76561197970982479
# 3        76561197970982479          277  76561197970982479
# 4        76561197970982479          277  76561197970982479
# ...                    ...          ...                ...
# 5983155  76561198135905916           69           codex131
# 5983156  76561198135905916           69           codex131
# 5983157  76561198135905916           69           codex131
# 5983158  76561198135905916           69           codex131
# 5983159  76561198135905916           69           codex131
#
#                                                 user_url_x  \
# 0        http://steamcommunity.com/profiles/76561197970...
# 1        http://steamcommunity.com/profiles/76561197970...
# 2        http://steamcommunity.com/profiles/76561197970...
# 3        http://steamcommunity.com/profiles/76561197970...
# 4        http://steamcommunity.com/profiles/76561197970...
# ...                                                    ...
# 5983155              http://steamcommunity.com/id/codex131
# 5983156              http://steamcommunity.com/id/codex131
# 5983157              http://steamcommunity.com/id/codex131
# 5983158              http://steamcommunity.com/id/codex131
# 5983159              http://steamcommunity.com/id/codex131
#
#                                                 user_url_y  reviews_item_id  \
# 0        http://steamcommunity.com/profiles/76561197970...             1250
# 1        http://steamcommunity.com/profiles/76561197970...            22200
# 2        http://steamcommunity.com/profiles/76561197970...            43110
# 3        http://steamcommunity.com/profiles/76561197970...             1250
# 4        http://steamcommunity.com/profiles/76561197970...            22200
# ...                                                    ...              ...
# 5983155              http://steamcommunity.com/id/codex131              730
# 5983156              http://steamcommunity.com/id/codex131              440
# 5983157              http://steamcommunity.com/id/codex131           273110
# 5983158              http://steamcommunity.com/id/codex131              730
# 5983159              http://steamcommunity.com/id/codex131              440
#
#                                        reviews_helpful  reviews_recommend  \
# 0                                       No ratings yet               True
# 1                                       No ratings yet               True
# 2                                       No ratings yet               True
# 3                                       No ratings yet               True
# 4                                       No ratings yet               True
# ...                                                ...                ...
# 5983155                                 No ratings yet               True
# 5983156                                 No ratings yet               True
# 5983157  1 of 2 people (50%) found this review helpful               True
# 5983158                                 No ratings yet               True
# 5983159                                 No ratings yet               True
#
#              reviews_date  sentiment_analysis
# 0              2011-11-05                   1
# 1              2011-07-15                   2
# 2              2011-04-21                   1
# 3              2011-11-05                   1
# 4              2011-07-15                   2
# ...                   ...                 ...
# 5983155  Formato inválido                   2
# 5983156  Formato inválido                   2
# 5983157  Formato inválido                   1
# 5983158  Formato inválido                   2
# 5983159  Formato inválido                   2
#
# [5983160 rows x 13 columns]

# %%
df_datosLimpios2 = pd.merge(df_datosLimpios, df_games_rename, how='inner', on='item_id')

# %%
df_datosLimpios2.columns
# Out:
# Index(['item_id', 'item_name', 'playtime_forever', 'steam_id', 'items_count',
#        'user_id', 'user_url_x', 'user_url_y', 'reviews_item_id',
#        'reviews_helpful', 'reviews_recommend', 'reviews_date',
#        'sentiment_analysis', 'genres', 'price', 'early_access', 'release_anio',
#        'publisher', 'app_name', 'title', 'developer'],
#       dtype='object')

# %% [markdown]
# ### Creo DF_DataExport

# %%
df_data = df_datosLimpios2[['release_anio','genres','playtime_forever','user_id','item_id', 'item_name','sentiment_analysis', 'reviews_recommend', 'reviews_date' ]]
df_data
# Out:
#          release_anio    genres  playtime_forever            user_id  item_id  \
# 0                2000    Action                 6  76561197970982479       10
# 1                2000    Action                 6  76561197970982479       10
# 2                2000    Action                 6  76561197970982479       10
# 3                2000    Action                 0            js41637       10
# 4                2000    Action                 0            js41637       10
# ...               ...       ...               ...                ...      ...
# 11854181         2016     Indie                 0              inven   433920
# 11854182         2016       RPG                 0              inven   433920
# 11854183         2015    Action               226  76561198134165301   352760
# 11854184         2015     Indie               226  76561198134165301   352760
# 11854185         2015  Strategy               226  76561198134165301   352760
#
#                               item_name  sentiment_analysis  \
# 0                        Counter-Strike                   1
# 1                        Counter-Strike                   2
# 2                        Counter-Strike                   1
# 3                        Counter-Strike                   1
# 4                        Counter-Strike                   1
# ...                                 ...                 ...
# 11854181  Aveyond 4: Shadow Of The Mist                   1
# 11854182  Aveyond 4: Shadow Of The Mist                   1
# 11854183                    Kaiju Panic                   1
# 11854184                    Kaiju Panic                   1
# 11854185                    Kaiju Panic                   1
#
#           reviews_recommend      reviews_date
# 0                      True        2011-11-05
# 1                      True        2011-07-15
# 2                      True        2011-04-21
# 3                      True        2014-06-24
# 4                      True        2013-09-08
# ...                     ...               ...
# 11854181               True        2015-04-06
# 11854182               True        2015-04-06
# 11854183               True  Formato inválido
# 11854184               True  Formato inválido
# 11854185               True  Formato inválido
#
# [11854186 rows x 9 columns]

# %%
#Modifico la fecha de reviews_date para extraer el año
df_data['reviews_date'] = pd.to_datetime(df_data['reviews_date'], errors='coerce')
df_data['reviews_anio'] = df_data['reviews_date'].dt.year

# %%
df_data
# Out:
#          release_anio    genres  playtime_forever            user_id  item_id  \
# 0                2000    Action                 6  76561197970982479       10
# 1                2000    Action                 6  76561197970982479       10
# 2                2000    Action                 6  76561197970982479       10
# 3                2000    Action                 0            js41637       10
# 4                2000    Action                 0            js41637       10
# ...               ...       ...               ...                ...      ...
# 11854181         2016     Indie                 0              inven   433920
# 11854182         2016       RPG                 0              inven   433920
# 11854183         2015    Action               226  76561198134165301   352760
# 11854184         2015     Indie               226  76561198134165301   352760
# 11854185         2015  Strategy               226  76561198134165301   352760
#
#                               item_name  sentiment_analysis  \
# 0                        Counter-Strike                   1
# 1                        Counter-Strike                   2
# 2                        Counter-Strike                   1
# 3                        Counter-Strike                   1
# 4                        Counter-Strike                   1
# ...                                 ...                 ...
# 11854181  Aveyond 4: Shadow Of The Mist                   1
# 11854182  Aveyond 4: Shadow Of The Mist                   1
# 11854183                    Kaiju Panic                   1
# 11854184                    Kaiju Panic                   1
# 11854185                    Kaiju Panic                   1
#
#           reviews_recommend reviews_date  reviews_anio
# 0                      True   2011-11-05        2011.0
# 1                      True   2011-07-15        2011.0
# 2                      True   2011-04-21        2011.0
# 3                      True   2014-06-24        2014.0
# 4                      True   2013-09-08        2013.0
# ...                     ...          ...           ...
# 11854181               True   2015-04-06        2015.0
# 11854182               True   2015-04-06        2015.0
# 11854183               True          NaT           NaN
# 11854184               True          NaT           NaN
# 11854185               True          NaT           NaN
#
# [11854186 rows x 10 columns]

# %%
#Elimino columnna Reviews date
df_data = df_data.drop('reviews_date', axis=1)

# %%
utils.types_data_df(df_data)
# Out:
#          nombre_campo                           tipo_datos  no_nulos_%  \
# 0        release_anio  [<class 'str'>, <class 'NoneType'>]       99.88
# 1              genres                      [<class 'str'>]      100.00
# 2    playtime_forever                      [<class 'int'>]      100.00
# 3             user_id                      [<class 'str'>]      100.00
# 4             item_id                      [<class 'int'>]      100.00
# 5           item_name                      [<class 'str'>]      100.00
# 6  sentiment_analysis                      [<class 'int'>]      100.00
# 7   reviews_recommend                     [<class 'bool'>]      100.00
# 8        reviews_anio                    [<class 'float'>]       82.39
#
#    nulos_%    nulos
# 0     0.12    14563
# 1     0.00        0
# 2     0.00        0
# 3     0.00        0
# 4     0.00        0
# 5     0.00        0
# 6     0.00        0
# 7     0.00        0
# 8    17.61  2087426

# %%
df_data['release_anio'] = pd.to_numeric(df_data['release_anio'], errors='coerce').astype('Int64')

# %%
df_data['reviews_anio'] = pd.to_numeric(df_data['reviews_anio'], errors='coerce').astype('Int64')

# %%
df_data.to_parquet('../data/data_export_api.parquet')

# %%
### guardo en compresion brotli
file_path_brotli = '../data/data_export_api_brotli.parquet'
df_data.to_parquet(file_path_brotli, engine='pyarrow', compression='brotli')

# %%
file_path_gzip = '../data/data_export_api_gzip.parquet'

# Guardar el DataFrame en un archivo Parquet comprimido con Gzip
df_data.to_parquet(file_path_gzip, engine='pyarrow', compression='gzip')
